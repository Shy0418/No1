# %%
# 同义词扩充
import pandas as pd
Existence1 = pd.read_table(r'E:\pythonProject\制作趋势词典\wordexpansion\test\词向量法\seeds\seed_words\Existence.txt',encoding='utf-8',header=None)
Existence1
# Out:
#          0
# 0       新冠
# 1       美国
# 2       新型
# 3       武汉
# 4       中国
# ...    ...
# 1076    护理
# 1077  卫生保健
# 1078    医护
# 1079    保健
# 1080    牙科
#
# [1081 rows x 1 columns]

# %%
Existence = Existence1[0].to_list()
Existence
# Out:
# ['新冠',
#  '美国',
#  '新型',
#  '武汉',
#  '中国',
#  '公司',
#  '口罩',
#  '行业',
#  '今年',
#  '黄金',
#  '湖北',
#  '世界',
#  '疫情',
#  '全国',
#  '李文亮',
#  '香港',
#  '德国',
#  '在家',
#  '治疗',
#  '国际',
#  '基金',
#  '英国',
#  '国外',
#  '新增',
#  '保险',
#  '钟南山',
#  '办公',
#  '美股',
#  '政府',
#  '国家',
#  '移民',
#  '加拿大',
#  '韩国',
#  '春节',
#  '城市',
#  '北京',
#  '手机',
#  '健康',
#  '事件',
#  '美联储',
#  '意大利',
#  '春暖花开',
#  '农村',
#  '东西',
#  '事情',
#  '治愈',
#  '医生',
#  '金融',
#  '新加坡',
#  '国内',
#  '护士',
#  '美团',
#  '原油',
#  '全面',
#  '转行',
#  '中小企业',
#  '京东',
#  '春季',
#  '泰国',
#  '瑞德',
#  '无法',
#  '杭州',
#  '公寓',
#  '四川',
#  '国产',
#  '天津',
#  '各国',
#  '钻石',
#  '曝光',
#  '美国政府',
#  '日本',
#  '保障',
#  '境外',
#  '湖北省',
#  '美元',
#  '五一',
#  '当下',
#  '天',
#  '浙江',
#  '地产',
#  '肺炎',
#  '冠状病毒',
#  '复工',
#  '病毒',
#  '现在',
#  '确诊',
#  '抗疫',
#  '防控',
#  '工作',
#  '隔离',
#  '防疫',
#  '感染',
#  '病例',
#  '爆发',
#  '医院',
#  '上班',
#  '推迟',
#  '患者',
#  '员工',
#  '医疗',
#  '战疫',
#  '美国',
#  '英国',
#  '加拿大',
#  '澳大利亚',
#  '墨西哥',
#  '澳洲',
#  '德国',
#  '古巴',
# ...

# %%
import synonyms
synonyms_data = []
with open(r'E:\pythonProject\制作趋势词典\wordexpansion\test\词向量法\seeds\seed_words\Existence_expand.txt',mode='w+',encoding='utf-8') as file:
    for i in Existence:
        sy = synonyms.nearby(i,10)[0]
        for j in sy:
            file.write(j+'\n')
            print(j)
    # synonyms_data.append(sy)
    # print(sy)
    # print('===========')
file.close()
# Out:
# Building prefix dict from d:\python3.8\lib\site-packages\synonyms\data\vocab.txt ...
# Loading model from cache C:\Users\Shy0418\AppData\Local\Temp\jieba.u4ffff3a26e04aaea5c89ddb932e881e1.cache
#  Synonyms: v3.18.0, Project home: https://github.com/chatopera/Synonyms/
#
#  Project Sponsored by Chatopera
#
#   deliver your chatbots with Chatopera Cloud Services --> https://bot.chatopera.com
#
# >> Synonyms load wordseg dict [d:\python3.8\lib\site-packages\synonyms\data\vocab.txt] ...
# Loading model cost 1.130 seconds.
# Prefix dict has been built successfully.
# >> Synonyms on loading stopwords [d:\python3.8\lib\site-packages\synonyms\data\stopwords.txt] ...
# >> Synonyms on loading vectors [d:\python3.8\lib\site-packages\synonyms\data\words.vector.gz] ...
# 美国
# 英国
# 加拿大
# 澳大利亚
# 墨西哥
# 澳洲
# 德国
# 古巴
# 哥伦比亚
# 新西兰
# 新型
# 新式
# 小型化
# 模块化
# 轻型
# 高科技
# 重型
# 通用型
# 实验性
# 新形态
# 武汉
# 重庆
# 长沙
# 南昌
# 南京
# 成都
# 杭州
# 湖北
# 合肥
# 郑州
# 中国
# 我国
# 亚洲
# 韩国
# 东亚
# 海外
# 欧美
# 国际上
# 亚洲地区
# 东亚地区
# 公司
# 子公司
# ...

# %%
import pandas as pd
Growth1 = pd.read_table(r'E:\pythonProject\制作趋势词典\wordexpansion\test\词向量法\seeds\seed_words\Growth.txt',encoding='utf-8',header=None)
Growth1
Growth = Growth1[0].to_list()
Growth

# %%
import synonyms
synonyms_data = []
with open(r'E:\pythonProject\制作趋势词典\wordexpansion\test\词向量法\seeds\seed_words\Growth_expand.txt',mode='w+',encoding='utf-8') as file:
 for i in Growth:
        sy = synonyms.nearby(i,10)[0]
        for j in sy:
            file.write(j+'\n')
            print(j)
file.close()

# %%
Relatedness1 = pd.read_table(r'E:\pythonProject\制作趋势词典\wordexpansion\test\词向量法\seeds\seed_words\Relatedness.txt',encoding='utf-8',header=None)
Relatedness1
Relatedness = Relatedness1[0].to_list()
Relatedness

# %%
import synonyms
with open(r'E:\pythonProject\制作趋势词典\wordexpansion\test\词向量法\seeds\seed_words\Relatedness_expand.txt',mode='w+',encoding='utf-8') as file:
    for i in Relatedness:
        sy = synonyms.nearby(i,10)[0]
        for j in sy:
            file.write(j+'\n')
            print(j)
file.close()
